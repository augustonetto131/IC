# %%
#Importando as bibliotecas

import pandas as pd
import os
import numpy as np
import string as st

# %%
os.chdir("C:/Users/gutao/OneDrive - Insper - Institudo de Ensino e Pesquisa/Documents/Insper/IC/IC_Data/Dataset")

portfolio = pd.read_csv("portfolio.csv", index_col=0)
portfolio = pd.read_csv("portfolio.csv", index_col=0)
portfolio = pd.read_csv("portfolio.csv", index_col=0)

# %%
portfolio.head(10)
# Out:
#     id         nome classe ticker  retorno_total       mkt_cap        ROE  \
# 1    1   Aco Altona     PN  EALT4     120.028802  9.297000e+04        NaN
# 2    7   Alpargatas     PN  ALPA4    3232.374818  7.372343e+05  19.521802
# 3    9    Ambev S/A     ON  ABEV3     716.379392  5.650664e+07  17.416903
# 4   11  Ampla Energ     ON  CBEE3      -0.086839  3.059562e+06  17.786310
# 5   14       Atmasa     ON  ATMP3     -99.780394  6.030010e+05  31.835469
# 6   18  B2W Digital     ON  BTOW3     211.215898  2.622998e+06  19.151681
# 7   19     Bardella     PN  BDLL4     -89.483863  2.143840e+05   6.052810
# 8   23        Biomm     ON  BIOM3            NaN  1.950300e+04        NaN
# 9   26      Bombril     PN  BOBR4     -50.843373  2.243698e+05        NaN
# 10  27    Bradespar     PN  BRAP4     254.620438  6.621177e+06  27.935386
#
#           ROA       ROIC  lucro_bruto  ...     alav_BS  EBIT_DivLiq  \
# 1   13.458083  33.671487      59430.0  ...  -76.535454  -398.748420
# 2    9.558172  12.039371     728831.0  ...   36.170848    96.358434
# 3    8.228157  14.157012   13735622.0  ...   63.311635    74.909570
# 4    6.270970   9.904009     799053.0  ...   98.534060    51.935925
# 5    9.309288  48.254032     284081.0  ...   76.540240  -105.769105
# 6    2.508533  20.957642     915472.0  ...  708.337548    37.456764
# 7    1.921962   4.768534      75688.0  ...   21.997230   132.166709
# 8  -60.903862 -39.049467        928.0  ...  -64.333661   -64.312072
# 9    1.471313  16.552473     321632.0  ...  -15.429477    75.023823
# 10   9.652527  13.678332    2230339.0  ...   49.836579   204.756047
#
#     ativo_growth  desvpad_ret  sharpe_economatica        div_yld      LPA_se  \
# 1     235.100989     1.270126            1.928985      20.054857    0.537248
# 2      98.380268     5.265005            0.775229       7.115483    0.064898
# 3     151.313533     5.495584            0.401450      43.305263    0.046291
# 4       8.699163     8.981943                 NaN      49.321579    1.361448
# 5            NaN  5945.782353           -0.375586  114228.595810  683.735713
# 6            NaN    11.569579            0.217917       0.324216    0.260761
# 7      98.343146    25.550824                 NaN     312.152350    3.862373
# 8            NaN     1.816620                 NaN       0.000000    0.352493
# 9     -18.613832     2.712598            0.570778       0.000000   18.276665
# 10    103.986514     7.630142            0.110628      33.779875    1.451458
#
#     sharpe_calc  provisoes   size
# 1      0.053529     3128.0  small
# 2      0.263395    97776.0  large
# 3      0.323162  1045491.0  large
# 4     -0.000193   405721.0  large
# 5     -0.304482    64151.0  small
# 6      0.095440     4270.0  large
# 7     -0.578685    27562.0  small
# 8           NaN        0.0  small
# 9     -0.057334        0.0  small
# 10     0.061854   372303.0  large
#
# [10 rows x 21 columns]
